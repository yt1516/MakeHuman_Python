# %%
import array
import random

import numpy

from deap import algorithms
from deap import base
from deap import creator
from deap import tools

IND_SIZE = 136

creator.create("FitnessMin", base.Fitness, weights=(-1.0,-1.0))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# Attribute generator
toolbox.register("attr_float", random.random)

# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=IND_SIZE)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# def evalOneMax(individual):
#     return sum(individual),

def minError(individual):
    points=[]
    with open('Asian_Men.jpg.txt') as file:
        for line in file:
            x,y=line.split()
            points.append(int(x))
            points.append(int(y))
    landmarks=points[0:68*2]
    errors=[]
    for i in range(len(landmarks)):
        errors.append(abs(landmarks[i]-individual[i]))
    return sum(errors)

toolbox.register("evaluate", minError)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

def main():
#     random.seed(64)
    
    pop = toolbox.population(n=500)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", numpy.mean)
    stats.register("std", numpy.std)
    stats.register("min", numpy.min)
    stats.register("max", numpy.max)
    
    pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=60, 
                                   stats=stats, halloffame=hof, verbose=True)
    
    return pop, log, hof

# %%
import array
import random

import numpy

from deap import algorithms
from deap import base
from deap import creator
from deap import tools

global points
points=[]
with open('Asian_Men.jpg.txt') as file:
    for line in file:
        x,y=line.split()
        points.append(int(x))
        points.append(int(y))
points=points[0:68*2]

IND_SIZE = 136

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# Attribute generator
toolbox.register("attr_float", random.uniform,0.8,1.2)


# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=IND_SIZE)

toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# ind1 = toolbox.individual()
# print(ind1)  

def minError(individual):

    landmarks=points
    errors=[]
    for i in range(len(landmarks)):
        errors.append(abs(landmarks[i]-landmarks[i]*individual[i]))
    return sum(errors),

toolbox.register("evaluate", minError)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

def main():
#     random.seed(64)
    
    pop = toolbox.population(n=4000)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
#     stats.register("avg", numpy.mean)
#     stats.register("std", numpy.std)
    stats.register("min", numpy.min)
#     stats.register("max", numpy.max)
    
    pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=200, 
                                   stats=stats, halloffame=hof, verbose=True)
    
#     return log#pop, log, hof

main()
# Out:
# gen	nevals	min
# 0  	4000  	8088.43
# 1  	2361  	7938.75
# 2  	2361  	7692.22
# 3  	2439  	7586.78
# 4  	2485  	7382.71
# 5  	2402  	7328.88
# 6  	2352  	6959.5
# 7  	2447  	6829
# 8  	2325  	6583.73
# 9  	2435  	6365.89
# 10 	2407  	6275.7
# 11 	2428  	5944.56
# 12 	2404  	6130.63
# 13 	2443  	5904.06
# 14 	2380  	5528.06
# 15 	2421  	5509.2
# 16 	2384  	5371.37
# 17 	2366  	5185.06
# 18 	2443  	4944.99
# 19 	2382  	5106.11
# 20 	2397  	4888.39
# 21 	2326  	4888.39
# 22 	2405  	4716.53
# 23 	2391  	4625.83
# 24 	2374  	4334.89
# 25 	2380  	4235.07
# 26 	2435  	4164.56
# 27 	2426  	3937.19
# 28 	2380  	3937.19
# 29 	2399  	3788.01
# 30 	2500  	3788.01
# 31 	2378  	3738.58
# 32 	2466  	3612.35
# 33 	2367  	3473.64
# 34 	2412  	3473.64
# 35 	2479  	3402.01
# 36 	2421  	3220.73
# 37 	2459  	3180.56
# 38 	2422  	3090.62
# 39 	2405  	3029.64
# 40 	2445  	2889.98
# 41 	2421  	2809.79
# 42 	2413  	2809.79
# 43 	2349  	2705.28
# 44 	2408  	2646.06
# 45 	2389  	2624.06
# 46 	2421  	2575.33
# ...
